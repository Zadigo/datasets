# %%
import pandas
import pathlib

# %%
files = list(pathlib.Path('.').glob('json/*.json'))

# %%
dfs = [pandas.read_json(file) for file in files]

# %%
df = pandas.concat(dfs, ignore_index=True)

# %%
df.head()
# Out:
#                   winner                details  \
# 0  Fairground Attraction     Best British Album
# 1           Annie Lennox    Best British Female
# 2                Erasure     Best British Group
# 3           Phil Collins      Best British Male
# 4                   Bros  Best British Newcomer
#
#                                                url  year       date  \
# 0  https://www.brits.co.uk/history/the-brits-1989/  1989 1989-02-13
# 1  https://www.brits.co.uk/history/the-brits-1989/  1989 1989-02-13
# 2  https://www.brits.co.uk/history/the-brits-1989/  1989 1989-02-13
# 3  https://www.brits.co.uk/history/the-brits-1989/  1989 1989-02-13
# 4  https://www.brits.co.uk/history/the-brits-1989/  1989 1989-02-13
#
#                     location                           host
# 0  Royal Albert Hall, London  Mick Fleetwood & Samantha Fox
# 1  Royal Albert Hall, London  Mick Fleetwood & Samantha Fox
# 2  Royal Albert Hall, London  Mick Fleetwood & Samantha Fox
# 3  Royal Albert Hall, London  Mick Fleetwood & Samantha Fox
# 4  Royal Albert Hall, London  Mick Fleetwood & Samantha Fox

# %%
def check_is_person(constraints: list[str]) -> callable:
    def wraped(name: str) -> bool:
        if not name:
            return False
        
        # values = ['Female', 'Male', 'Newcomer', 'Group', 'Artist']

        result = False
        for value in constraints:
            if value in name:
                result = True
                break
        return result
    return wraped

# %%
df['is_person'] = df.details.map(check_is_person(
    [
        'Female', 
        'Male', 
        'Newcomer', 
        'Group', 
        'Artist',
        'Outstanding Contribution',
        'British Breakthrough',
        'Act'
    ]
))

# %%
df['is_album_or_single'] = df.details.map(check_is_person(['Album', 'Single']))

# %%
artists = df[df.winner.isna() == False & (df.winner != '')]['winner'].drop_duplicates()

# %%
artists.to_csv('brit_awards_artists.csv', index=False)

# %%
df.to_csv('brit_awards.csv', index=False)
