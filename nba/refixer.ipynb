# %%
import pandas
import pathlib

# %%
BASE_DIR = pathlib.Path('./').absolute()
BASE_DIR
# Out:
# PosixPath('/Volumes/Coding/Projects/Open-Source/datasets/nba')

# %%
df = pandas.read_csv(BASE_DIR / '1996.csv')

# %%
df.sort_values('PTS', inplace=True, ascending=False)

# %%
df.head()
# Out:
#    ID            Player Team  Age  GP   W   L     Min   PTS  FGM  ...  REB  \
# 0   1    Michael Jordan  CHI   34  82  69  13  3108.8  2431  920  ...  482
# 1   2       Karl Malone  UTA   33  82  64  18  2997.7  2249  864  ...  809
# 2   3         Glen Rice  CHH   30  79  52  27  3359.0  2115  722  ...  318
# 3   4    Mitch Richmond  SAC   32  81  34  47  3124.8  2095  717  ...  319
# 4   5  Latrell Sprewell  GSW   26  80  29  51  3349.8  1938  649  ...  366
#
#    AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-
# 0  352  166  140   44  156  3923    9    1  820
# 1  368  233  113   48  216  4022   43    1  767
# 2  160  177   72   26  190  2854    0    0  176
# 3  338  237  118   24  206  3174    4    1 -153
# 4  507  322  133   45  153  3350   15    1 -216
#
# [5 rows x 30 columns]
