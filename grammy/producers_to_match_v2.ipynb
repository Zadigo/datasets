# %%
import csv
import json
import pathlib
import pandas

# %%
grammies = list(csv.reader(pathlib.Path('grammy_winners_v2.csv').open()))

# %%
grammies[:2]
# Out:
# [['id',
#   'year',
#   'subtitle',
#   'category',
#   'artist',
#   'song_or_album',
#   'url',
#   'producers',
#   'winner'],
#  ['7144',
#   '1958',
#   '1St Annual Grammy Awards',
#   'Song Of The Year',
#   'Cy Coleman & Carolyn Leigh, songwriters (Frank Sinatra)',
#   'Witchcraft (Single)',
#   'https://www.grammy.com/awards/1st-annual-grammy-awards',
#   '',
#   'False']]

# %%
with open(pathlib.Path('tmp/producers_to_match.json'), 'r') as f:
    producers_to_match = json.load(f)

# %%
YEAR = 1958

# %%
for item in producers_to_match:
    if item['producers'] is not None:
        for csv_value in grammies:
            if csv_value[-1] == 'False':
                continue

            if csv_value[1] == f'{YEAR}':
                logic = [
                    csv_value[3].lower() == item['award'].lower(),
                    (
                        csv_value[4].lower() == item['title'].lower() or
                        csv_value[5].lower() == item['title'].lower()
                    )
                ]
                if all(logic):
                    csv_value[7] = item['producers']
                    if item['producers'] is None:
                        continue
                    
                    print(f"Match found: {csv_value[1]} - {csv_value[3]}")
                    continue
# Out:
# Match found: 1958 - Song Of The Year
# Match found: 1958 - Best Arrangement
# Match found: 1958 - Best Engineered Record (Classical)
# Match found: 1958 - Best Engineered Record - Non-Classical
# Match found: 1958 - Best Album Cover
# Match found: 1958 - Best Musical Composition First Recorded And Released In 1958 (Over 5 Minutes Duration)
# Match found: 1958 - Best Original Cast Album (Broadway Or TV)
# Match found: 1958 - Best Classical Performance - Orchestra
# Match found: 1958 - Best Classical Performance - Instrumentalist (With Concerto Scale Accompaniment)
# Match found: 1958 - Best Classical Performance - Chamber Music (Including Chamber Orchestra)
# Match found: 1958 - Best Classical Performance - Vocal Soloist (With Or Without Orchestra)
# Match found: 1958 - Best Classical Performance - Operatic Or Choral

# %%
df = pandas.DataFrame(grammies, columns=grammies.pop(0))

# %%
df[df.year == f'{YEAR}'][['id', 'song_or_album', 'producers']]
# Out:
#        id                                      song_or_album producers
# 0    7144                                Witchcraft (Single)
# 1    7145                                      Gigi (Single)
# 2    7146                                              Fever
# 3    7147                               Catch A Falling Star
# 4    7148  Ella Fitzgerald Sings The Irving Berlin Song Book
# ..    ...                                                ...       ...
# 142  7170                         Baubles, Bangles And Beads
# 143  7171                               That Old Black Magic
# 144  7137                               Catch A Falling Star
# 145  7138                          The Music From Peter Gunn
# 146  7139  Tchaikovsky: Concerto No. 1, In B-Flat Minor, ...
#
# [147 rows x 3 columns]

# %%
df.to_csv(pathlib.Path('grammy_winners_v2.csv'), index=False)
