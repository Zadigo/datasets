# %%
import pandas

# %%
df = pandas.read_json('fr_code_postal.json')

# %%
df.describe()
# Out:
#         code_postal
# count  39192.000000
# mean   46807.191544
# std    25899.694423
# min     1000.000000
# 25%    24800.000000
# 50%    49360.000000
# 75%    67350.000000
# max    98890.000000

# %%
duplicates = df[df.duplicated(subset=['commune'])]

# %%
duplicates.insee.count()
# Out:
# np.int64(6416)

# %%
df.dropna(subset=['commune', 'code_postal', 'gps'], inplace=True)

# %%
df.sort_values('commune', inplace=True)

# %%
df.insee.count()
# Out:
# np.int64(38922)

# %%
df.to_csv('fr_code_postal_v2.csv', index=False)
